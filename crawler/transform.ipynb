# %% [markdown]
# # Transform Phenotypic Data into a Common Format
# This script accesses the extracted data in their original format and applys a mapping to harmonize the data into a common tabular format.

# %%
import os
import json
import glob

import numpy as np
import pandas as pd

# %%
# Path to repositories to pull raw data out of.
curdir = os.path.abspath(os.path.curdir)
repos = ['fcp-indi']
extract_paths = [os.path.join(curdir, repo) for repo in repos]
# Path to where the tranformed projects will go.
xfm_dir = os.path.join(curdir, 'metadata')
if not os.path.exists(xfm_dir):
    os.mkdir(xfm_dir)
# Project dirs.
extract_dirs = list()
for extract_path in extract_paths:
    project_paths = [os.path.join(extract_path, project) for project in os.listdir(extract_path) if '.' not in project]
    extract_dirs.extend(project_paths)

# %%
def apply_mapping(mapping, df_list):
    """
    Reads a dictionary mapping and list of dataframe, then merges the
    dataframes and convers the column name and values into a common
    format. Note: the dataframes should have a common structure.
    
    Example Mapping Structure
    =========================
    {  
        "DX_GROUP":
      {
        "element": "diagnosis",
        "type": "category",
        "1": "autism",
        "2": "control"
      }
    }
    """
    results = list()
    csv = pd.concat(df_list)
    csv.reset_index(drop=True, inplace=True)
    for col, elem in mapping.iteritems():
        # Use get in case the col is missing/static.
        series = csv.get(col)
        # Categories are mapped to common values.
        if elem.get('type') == 'str':
            result = series.apply(lambda x: elem.get(str(x)))
        # Values parsed as numbers are checked for any mappings (e.g., -999 == NaN).
        elif elem.get('type') == 'float':
            result = series.apply(lambda x: np.NaN if str(x) in elem.keys() else x)
        # Used to create a column of all the same value.
        elif elem.get('type') == 'static':
            val = [elem.get('value')] * csv.shape[0]
            result = pd.Series(val, index=csv.index)
        else:
            try:
                # Handle IDs being read as float.
                result = series.apply(lambda x: str(int(x)) if pd.notnull(x) else x)
            except ValueError as e:
                result = series
        # Concat all csv in a extract dir into one dataframe.        
        df = pd.DataFrame()
        df[elem.get('element')] = result
        results.append(df)
        concat = pd.concat(results, axis=1)
    # Merge any columns with duplicate names to fil in NaN from concat step.
    return concat.groupby(level=0, axis=1).first()

# %%
# Read a mapping.json file from each sub directory to process.
for extract_dir in extract_dirs:
    df_list = list()
    mapping = dict()
    project_name = extract_dir.split('/')[-1]
    # All files must use the same data dictionary in a given directory.
    extract_files = [os.path.join(extract_dir, i) for i in os.listdir(extract_dir) if i not in ['mapping.json']]
    mapping_file = os.path.join(extract_dir, 'mapping.json')
    if os.path.exists(mapping_file):
        with open(mapping_file, 'rb') as fi:
            mapping.update(json.load(fi))
        ext_type = dict(csv=',', tsv='\t')
        # Grab dtype for parsing csv
        dtype = {k: v.get('type') for k, v in mapping.iteritems() if v.get('type') in ['str', 'int', 'float']}
        dtype.update({k: 'str' for k, v in mapping.iteritems() if v.get('type') in ['static']})
        # Dealing with NaNs.
        na_values = ['NoPhenotypicData', '#']
        for extract_file in extract_files:
            # Process each file.
            ext = extract_file.split('.')[-1]
            sep_type = ext_type.get(ext)
            df = pd.read_csv(extract_file, sep=sep_type, dtype=dtype, na_values=na_values)
            df_list.append(df.drop_duplicates())
        xfm = apply_mapping(mapping, df_list)
        pheno_file = ''.join([project_name, '_', 'phenotype.csv'])
        pheno_path = os.path.join(xfm_dir, pheno_file)
        xfm.to_csv(pheno_path, index=False)

# %%
# Merge all the transformed files into a single frame
meta_files = glob.glob(xfm_dir + '/*.csv')
meta_list = list()
for meta_file in meta_files:
    df = pd.read_csv(meta_file, dtype={'session_id': 'str',
                                       'participant_id': 'str'})
    meta_list.append(df)
meta_df = pd.concat(meta_list).set_index(['project', 'session_id', 'participant_id'])
meta = meta_df.drop_duplicates()
meta.head()
# Out:
#                                               age diagnosis dsm_iv_tr  \
# project          session_id participant_id
# abide_initiative 1          50002           16.77    autism    autism
#                             50003           24.45    autism    autism
#                             50004           19.09    autism    autism
#                             50005           13.73    autism    autism
#                             50006           13.37    autism    autism
#
#                                             full iq    handedness  \
# project          session_id participant_id
# abide_initiative 1          50002             103.0  ambidextrous
#                             50003             124.0  right handed
#                             50004             113.0  right handed
#                             50005             119.0  right handed
#                             50006             109.0   left handed
#
#                                             performance iq     sex site_id  \
# project          session_id participant_id
# abide_initiative 1          50002                     89.0    Male    PITT
#                             50003                    115.0    Male    PITT
#                             50004                    117.0    Male    PITT
#                             50005                    118.0  Female    PITT
#                             50006                    119.0    Male    PITT
#
#                                                  species  verbal iq
# project          session_id participant_id
# abide_initiative 1          50002           homo-sapiens      116.0
#                             50003           homo-sapiens      128.0
#                             50004           homo-sapiens      108.0
#                             50005           homo-sapiens      117.0
#                             50006           homo-sapiens       99.0

# %%
# Load the CSV with MRI URLs
mri_path = os.path.abspath('clean-csv/all-session.csv')
mri = pd.read_csv(mri_path).set_index(['project', 'session_id', 'participant_id'])
mri.head()
# Out:
#                                                                                        t1_url  \
# project          session_id participant_id
# abide_initiative 1          50002           https://s3.amazonaws.com/fcp-indi/data/Project...
#                             50003           https://s3.amazonaws.com/fcp-indi/data/Project...
#                             50004           https://s3.amazonaws.com/fcp-indi/data/Project...
#                             50005           https://s3.amazonaws.com/fcp-indi/data/Project...
#                             50006           https://s3.amazonaws.com/fcp-indi/data/Project...
#
#                                             session_count
# project          session_id participant_id
# abide_initiative 1          50002                       1
#                             50003                       1
#                             50004                       1
#                             50005                       1
#                             50006                       1

# %%
# Grab only the records with unique indices (NKI-RS has duplicate records and needs to be cleaned)
dups = meta.loc[meta.index.duplicated()]
only_unique = meta.loc[~meta.index.duplicated()]
unique = pd.concat([only_unique, dups])

# %%
# Merge Datasets
joined = unique.join(mri, how='outer')
joined['mri'] = joined.t1_url.apply(lambda x: 'no' if pd.isnull(x) else 'yes')
final = joined.reset_index()

# %%
final.to_csv('../docs/da')
# Out:
#                project session_id participant_id    age diagnosis dsm_iv_tr  \
# 0     abide_initiative          1          50002  16.77    autism    autism
# 1     abide_initiative          1          50003  24.45    autism    autism
# 2     abide_initiative          1          50004  19.09    autism    autism
# 3     abide_initiative          1          50005  13.73    autism    autism
# 4     abide_initiative          1          50006  13.37    autism    autism
# 5     abide_initiative          1          50007  17.78    autism    autism
# 6     abide_initiative          1          50008  32.45    autism    autism
# 7     abide_initiative          1          50009  33.86    autism    autism
# 8     abide_initiative          1          50010  35.20    autism    autism
# 9     abide_initiative          1          50011  16.93    autism    autism
# 10    abide_initiative          1          50012  21.48    autism    autism
# 11    abide_initiative          1          50013   9.33    autism    autism
# 12    abide_initiative          1          50014  14.20    autism    autism
# 13    abide_initiative          1          50015  14.20    autism    autism
# 14    abide_initiative          1          50016  21.82    autism    autism
# 15    abide_initiative          1          50017  22.70    autism    autism
# 16    abide_initiative          1          50019  27.81    autism    autism
# 17    abide_initiative          1          50020  20.83    autism    autism
# 18    abide_initiative          1          50022  16.99    autism    autism
# 19    abide_initiative          1          50023  12.64    autism    autism
# 20    abide_initiative          1          50024  22.64    autism    autism
# 21    abide_initiative          1          50025  31.72    autism    autism
# 22    abide_initiative          1          50026  16.28    autism    autism
# 23    abide_initiative          1          50027  12.24    autism    autism
# 24    abide_initiative          1          50028  12.74    autism    autism
# 25    abide_initiative          1          50029  11.40    autism    autism
# 26    abide_initiative          1          50030  25.12   control   control
# 27    abide_initiative          1          50031  12.92   control   control
# 28    abide_initiative          1          50032  19.80   control   control
# 29    abide_initiative          1          50033  12.15   control   control
# ...                ...        ...            ...    ...       ...       ...
# 7685    rocklandsample      nfb_3      A00056556    NaN       NaN       NaN
# 7686    rocklandsample      nfb_3      A00056627    NaN       NaN       NaN
# 7687    rocklandsample      nfb_3      A00057203    NaN       NaN       NaN
# 7688    rocklandsample      nfb_3      A00057235    NaN       NaN       NaN
# 7689    rocklandsample      nfb_3      A00057372    NaN       NaN       NaN
# 7690    rocklandsample      nfb_3      A00057444    NaN       NaN       NaN
# 7691    rocklandsample      nfb_3      A00057786    NaN       NaN       NaN
# 7692    rocklandsample      nfb_3      A00057808    NaN       NaN       NaN
# 7693    rocklandsample      nfb_3      A00057965    NaN       NaN       NaN
# 7694    rocklandsample      nfb_3      A00058214    NaN       NaN       NaN
# 7695    rocklandsample      nfb_3      A00058218    NaN       NaN       NaN
# 7696    rocklandsample      nfb_3      A00058503    NaN       NaN       NaN
# 7697    rocklandsample      nfb_3      A00058552    NaN       NaN       NaN
# 7698    rocklandsample      nfb_3      A00058667    NaN       NaN       NaN
# 7699    rocklandsample      nfb_3      A00058952    NaN       NaN       NaN
# 7700    rocklandsample      nfb_3      A00058999    NaN       NaN       NaN
# 7701    rocklandsample      nfb_3      A00059344    NaN       NaN       NaN
# 7702    rocklandsample      nfb_3      A00059346    NaN       NaN       NaN
# 7703    rocklandsample      nfb_3      A00059428    NaN       NaN       NaN
# 7704    rocklandsample      nfb_3      A00059756    NaN       NaN       NaN
# 7705    rocklandsample      nfb_3      A00059845    NaN       NaN       NaN
# 7706    rocklandsample      nfb_3      A00059911    NaN       NaN       NaN
# 7707    rocklandsample      nfb_3      A00060006    NaN       NaN       NaN
# 7708    rocklandsample      nfb_3      A00060169    NaN       NaN       NaN
# 7709    rocklandsample      nfb_3      A00060279    NaN       NaN       NaN
# 7710    rocklandsample      nfb_3      A00060372    NaN       NaN       NaN
# 7711    rocklandsample      nfb_3      A00060430    NaN       NaN       NaN
# 7712    rocklandsample      nfb_3      A00060471    NaN       NaN       NaN
# 7713    rocklandsample      nfb_3      A00060480    NaN       NaN       NaN
# 7714    rocklandsample      nfb_3      A00060516    NaN       NaN       NaN
#
#       full iq    handedness  performance iq     sex site_id       species  \
# 0       103.0  ambidextrous            89.0    Male    PITT  homo-sapiens
# 1       124.0  right handed           115.0    Male    PITT  homo-sapiens
# 2       113.0  right handed           117.0    Male    PITT  homo-sapiens
# 3       119.0  right handed           118.0  Female    PITT  homo-sapiens
# 4       109.0   left handed           119.0    Male    PITT  homo-sapiens
# 5       110.0  right handed           112.0    Male    PITT  homo-sapiens
# 6       123.0  right handed           114.0    Male    PITT  homo-sapiens
# 7       126.0  right handed           128.0    Male    PITT  homo-sapiens
# 8        81.0   left handed            93.0    Male    PITT  homo-sapiens
# 9       111.0   left handed           120.0    Male    PITT  homo-sapiens
# 10      128.0  right handed           128.0    Male    PITT  homo-sapiens
# 11       86.0  right handed            87.0    Male    PITT  homo-sapiens
# 12       96.0  right handed            96.0    Male    PITT  homo-sapiens
# 13       99.0  right handed            99.0    Male    PITT  homo-sapiens
# 14      123.0  right handed           119.0    Male    PITT  homo-sapiens
# 15       87.0  right handed            86.0    Male    PITT  homo-sapiens
# 16      100.0  right handed           111.0    Male    PITT  homo-sapiens
# 17      100.0  right handed            83.0    Male    PITT  homo-sapiens
# 18      119.0  right handed           110.0    Male    PITT  homo-sapiens
# 19       97.0  right handed           111.0  Female    PITT  homo-sapiens
# 20      127.0  right handed           126.0    Male    PITT  homo-sapiens
# 21      131.0  right handed           123.0    Male    PITT  homo-sapiens
# 22       87.0  right handed            88.0    Male    PITT  homo-sapiens
# 23       98.0  right handed            98.0    Male    PITT  homo-sapiens
# 24      126.0  right handed           128.0    Male    PITT  homo-sapiens
# 25      106.0  right handed           100.0  Female    PITT  homo-sapiens
# 26      105.0           NaN           108.0    Male    PITT  homo-sapiens
# 27      106.0  right handed           107.0    Male    PITT  homo-sapiens
# 28      119.0  right handed           119.0    Male    PITT  homo-sapiens
# 29       98.0  right handed            96.0    Male    PITT  homo-sapiens
# ...       ...           ...             ...     ...     ...           ...
# 7685      NaN           NaN             NaN     NaN     NaN           NaN
# 7686      NaN           NaN             NaN     NaN     NaN           NaN
# 7687      NaN           NaN             NaN     NaN     NaN           NaN
# 7688      NaN           NaN             NaN     NaN     NaN           NaN
# 7689      NaN           NaN             NaN     NaN     NaN           NaN
# 7690      NaN           NaN             NaN     NaN     NaN           NaN
# 7691      NaN           NaN             NaN     NaN     NaN           NaN
# 7692      NaN           NaN             NaN     NaN     NaN           NaN
# 7693      NaN           NaN             NaN     NaN     NaN           NaN
# 7694      NaN           NaN             NaN     NaN     NaN           NaN
# 7695      NaN           NaN             NaN     NaN     NaN           NaN
# 7696      NaN           NaN             NaN     NaN     NaN           NaN
# 7697      NaN           NaN             NaN     NaN     NaN           NaN
# 7698      NaN           NaN             NaN     NaN     NaN           NaN
# 7699      NaN           NaN             NaN     NaN     NaN           NaN
# 7700      NaN           NaN             NaN     NaN     NaN           NaN
# 7701      NaN           NaN             NaN     NaN     NaN           NaN
# 7702      NaN           NaN             NaN     NaN     NaN           NaN
# 7703      NaN           NaN             NaN     NaN     NaN           NaN
# 7704      NaN           NaN             NaN     NaN     NaN           NaN
# 7705      NaN           NaN             NaN     NaN     NaN           NaN
# 7706      NaN           NaN             NaN     NaN     NaN           NaN
# 7707      NaN           NaN             NaN     NaN     NaN           NaN
# 7708      NaN           NaN             NaN     NaN     NaN           NaN
# 7709      NaN           NaN             NaN     NaN     NaN           NaN
# 7710      NaN           NaN             NaN     NaN     NaN           NaN
# 7711      NaN           NaN             NaN     NaN     NaN           NaN
# 7712      NaN           NaN             NaN     NaN     NaN           NaN
# 7713      NaN           NaN             NaN     NaN     NaN           NaN
# 7714      NaN           NaN             NaN     NaN     NaN           NaN
#
#       verbal iq                                             t1_url  \
# 0         116.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 1         128.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 2         108.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 3         117.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 4          99.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 5         106.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 6         123.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7         118.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 8          81.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 9         101.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 10        119.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 11         89.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 12         97.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 13         98.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 14        120.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 15         91.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 16         89.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 17        120.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 18        110.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 19         83.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 20        121.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 21        132.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 22         90.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 23         98.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 24        112.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 25        109.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 26        100.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 27        102.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 28        116.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# 29         98.0  https://s3.amazonaws.com/fcp-indi/data/Project...
# ...         ...                                                ...
# 7685        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7686        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7687        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7688        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7689        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7690        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7691        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7692        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7693        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7694        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7695        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7696        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7697        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7698        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7699        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7700        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7701        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7702        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7703        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7704        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7705        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7706        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7707        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7708        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7709        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7710        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7711        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7712        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7713        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
# 7714        NaN  https://s3.amazonaws.com/fcp-indi/data/Project...
#
#       session_count  mri
# 0               1.0  yes
# 1               1.0  yes
# 2               1.0  yes
# 3               1.0  yes
# 4               1.0  yes
# 5               1.0  yes
# 6               1.0  yes
# 7               1.0  yes
# 8               1.0  yes
# 9               1.0  yes
# 10              1.0  yes
# 11              1.0  yes
# 12              1.0  yes
# 13              1.0  yes
# 14              1.0  yes
# 15              1.0  yes
# 16              1.0  yes
# 17              1.0  yes
# 18              1.0  yes
# 19              1.0  yes
# 20              1.0  yes
# 21              1.0  yes
# 22              1.0  yes
# 23              1.0  yes
# 24              1.0  yes
# 25              1.0  yes
# 26              1.0  yes
# 27              1.0  yes
# 28              1.0  yes
# 29              1.0  yes
# ...             ...  ...
# 7685            1.0  yes
# 7686            1.0  yes
# 7687            1.0  yes
# 7688            1.0  yes
# 7689            1.0  yes
# 7690            1.0  yes
# 7691            1.0  yes
# 7692            1.0  yes
# 7693            1.0  yes
# 7694            1.0  yes
# 7695            1.0  yes
# 7696            1.0  yes
# 7697            1.0  yes
# 7698            1.0  yes
# 7699            1.0  yes
# 7700            1.0  yes
# 7701            1.0  yes
# 7702            1.0  yes
# 7703            1.0  yes
# 7704            1.0  yes
# 7705            1.0  yes
# 7706            1.0  yes
# 7707            1.0  yes
# 7708            1.0  yes
# 7709            1.0  yes
# 7710            1.0  yes
# 7711            1.0  yes
# 7712            1.0  yes
# 7713            1.0  yes
# 7714            1.0  yes
#
# [7715 rows x 16 columns]

# %%
# Out:
# (7951, 13)
