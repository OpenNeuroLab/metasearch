# %% [markdown]
# # Transform Phenotypic Data into a Common Format
# This script accesses the extracted data in their original format and applys a mapping to harmonize the data into a common tabular format.

# %%
import os
import json
import glob

import numpy as np
import pandas as pd

# %%
# Path to repositories to pull raw data out of.
curdir = os.path.abspath(os.path.curdir)
repos = ['fcp-indi']
extract_paths = [os.path.join(curdir, repo) for repo in repos]
# Path to where the tranformed projects will go.
xfm_dir = os.path.join(curdir, 'metadata')
if not os.path.exists(xfm_dir):
    os.mkdir(xfm_dir)
# Project dirs.
extract_dirs = list()
for extract_path in extract_paths:
    project_paths = [os.path.join(extract_path, project) for project in os.listdir(extract_path) if '.' not in project]
    extract_dirs.extend(project_paths)

# %%
def apply_mapping(mapping, df_list):
    """
    Reads a dictionary mapping and list of dataframe, then merges the
    dataframes and convers the column name and values into a common
    format. Note: the dataframes should have a common structure.
    
    Example Mapping Structure
    =========================
    {  
        "DX_GROUP":
      {
        "element": "diagnosis",
        "type": "category",
        "1": "autism",
        "2": "control"
      }
    }
    """
    results = list()
    csv = pd.concat(df_list)
    csv.reset_index(drop=True, inplace=True)
    for col, elem in mapping.iteritems():
        # Use get in case the col is missing/static.
        series = csv.get(col)
        # Categories are mapped to common values.
        if elem.get('type') == 'str':
            result = series.apply(lambda x: elem.get(str(x)))
        # Values parsed as numbers are checked for any mappings (e.g., -999 == NaN).
        elif elem.get('type') == 'float':
            result = series.apply(lambda x: np.NaN if str(x) in elem.keys() else x)
        # Used to create a column of all the same value.
        elif elem.get('type') == 'static':
            val = [elem.get('value')] * csv.shape[0]
            result = pd.Series(val, index=csv.index)
        else:
            try:
                # Handle IDs being read as float.
                result = series.apply(lambda x: str(int(x)) if pd.notnull(x) else x)
            except ValueError as e:
                result = series
        # Concat all csv in a extract dir into one dataframe.        
        df = pd.DataFrame()
        df[elem.get('element')] = result
        results.append(df)
        concat = pd.concat(results, axis=1)
    # Merge any columns with duplicate names to fil in NaN from concat step.
    return concat.groupby(level=0, axis=1).first()

# %%
# Read a mapping.json file from each sub directory to process.
for extract_dir in extract_dirs:
    df_list = list()
    mapping = dict()
    project_name = extract_dir.split('/')[-1]
    # All files must use the same data dictionary in a given directory.
    extract_files = [os.path.join(extract_dir, i) for i in os.listdir(extract_dir) if i not in ['mapping.json']]
    mapping_file = os.path.join(extract_dir, 'mapping.json')
    if os.path.exists(mapping_file):
        with open(mapping_file, 'rb') as fi:
            mapping.update(json.load(fi))
        ext_type = dict(csv=',', tsv='\t')
        # Grab dtype for parsing csv
        dtype = {k: v.get('type') for k, v in mapping.iteritems() if v.get('type') in ['str', 'int', 'float']}
        dtype.update({k: 'str' for k, v in mapping.iteritems() if v.get('type') in ['static']})
        # Dealing with NaNs.
        na_values = ['NoPhenotypicData', '#']
        for extract_file in extract_files:
            # Process each file.
            ext = extract_file.split('.')[-1]
            sep_type = ext_type.get(ext)
            df = pd.read_csv(extract_file, sep=sep_type, dtype=dtype, na_values=na_values)
            df_list.append(df)
        xfm = apply_mapping(mapping, df_list)
        pheno_file = ''.join([project_name, '_', 'phenotype.csv'])
        pheno_path = os.path.join(xfm_dir, pheno_file)
        xfm.to_csv(pheno_path, index=False)

# %%
# Merge all the transformed files into a single frame
meta_files = glob.glob(xfm_dir + '/*.csv')
meta_list = list()
for meta_file in meta_files:
    df = pd.read_csv(meta_file)
    meta_list.append(df)
meta_df = pd.concat(meta_list).set_index(['project', 'session_id', 'participant_id'], drop=False)
meta_df.head()
# Out:
#                                               age diagnosis dsm_iv_tr  \
# project          session_id participant_id
# abide_initiative 1          50002           16.77    autism    autism
#                             50003           24.45    autism    autism
#                             50004           19.09    autism    autism
#                             50005           13.73    autism    autism
#                             50006           13.37    autism    autism
#
#                                             full iq    handedness  \
# project          session_id participant_id
# abide_initiative 1          50002             103.0  ambidextrous
#                             50003             124.0  right handed
#                             50004             113.0  right handed
#                             50005             119.0  right handed
#                             50006             109.0   left handed
#
#                                            participant_id  performance iq  \
# project          session_id participant_id
# abide_initiative 1          50002                   50002            89.0
#                             50003                   50003           115.0
#                             50004                   50004           117.0
#                             50005                   50005           118.0
#                             50006                   50006           119.0
#
#                                                      project session_id  \
# project          session_id participant_id
# abide_initiative 1          50002           abide_initiative          1
#                             50003           abide_initiative          1
#                             50004           abide_initiative          1
#                             50005           abide_initiative          1
#                             50006           abide_initiative          1
#
#                                                sex site_id       species  \
# project          session_id participant_id
# abide_initiative 1          50002             Male    PITT  homo-sapiens
#                             50003             Male    PITT  homo-sapiens
#                             50004             Male    PITT  homo-sapiens
#                             50005           Female    PITT  homo-sapiens
#                             50006             Male    PITT  homo-sapiens
#
#                                             verbal iq
# project          session_id participant_id
# abide_initiative 1          50002               116.0
#                             50003               128.0
#                             50004               108.0
#                             50005               117.0
#                             50006                99.0

# %%
# Load the CSV with MRI URLs
mri_path = os.path.abspath('clean-csv/all-session.csv')
mri = pd.read_csv(mri_path).set_index(['project', 'session_id', 'participant_id'], drop=False)
mri.head()
# Out:
#                                                                               t1_url  \
# project session_id participant_id
# acpi    1          0028031         https://s3.amazonaws.com/fcp-indi/data/Project...
#                    0028032         https://s3.amazonaws.com/fcp-indi/data/Project...
#                    0028033         https://s3.amazonaws.com/fcp-indi/data/Project...
#                    0028034         https://s3.amazonaws.com/fcp-indi/data/Project...
#                    0028035         https://s3.amazonaws.com/fcp-indi/data/Project...
#
#                                   participant_id project session_id  \
# project session_id participant_id
# acpi    1          0028031               0028031    acpi          1
#                    0028032               0028032    acpi          1
#                    0028033               0028033    acpi          1
#                    0028034               0028034    acpi          1
#                    0028035               0028035    acpi          1
#
#                                    session_count
# project session_id participant_id
# acpi    1          0028031                     1
#                    0028032                     1
#                    0028033                     1
#                    0028034                     1
#                    0028035                     1

# %%
r = pd.concat([meta_df, mri])

# %%
foo = {k: v.get('type') for k, v in mapping.iteritems() if v.get('type') in ['str', 'float']}

# %%
pd.read_csv('fcp-indi/abide_initiative/Phenotypic_V1_0b_preprocessed1.csv', dtype=foo)
# Out:
#       Unnamed: 0  Unnamed: 0.1  SUB_ID     X  subject  SITE_ID  \
# 0              0             1   50002     1    50002     PITT
# 1              1             2   50003     2    50003     PITT
# 2              2             3   50004     3    50004     PITT
# 3              3             4   50005     4    50005     PITT
# 4              4             5   50006     5    50006     PITT
# 5              5             6   50007     6    50007     PITT
# 6              6             7   50008     7    50008     PITT
# 7              7             8   50009     8    50009     PITT
# 8              8             9   50010     9    50010     PITT
# 9              9            10   50011    10    50011     PITT
# 10            10            11   50012    11    50012     PITT
# 11            11            12   50013    12    50013     PITT
# 12            12            13   50014    13    50014     PITT
# 13            13            14   50015    14    50015     PITT
# 14            14            15   50016    15    50016     PITT
# 15            15            16   50017    16    50017     PITT
# 16            16            17   50019    17    50019     PITT
# 17            17            18   50020    18    50020     PITT
# 18            18            19   50022    19    50022     PITT
# 19            19            20   50023    20    50023     PITT
# 20            20            21   50024    21    50024     PITT
# 21            21            22   50025    22    50025     PITT
# 22            22            23   50026    23    50026     PITT
# 23            23            24   50027    24    50027     PITT
# 24            24            25   50028    25    50028     PITT
# 25            25            26   50029    26    50029     PITT
# 26            26            27   50030    27    50030     PITT
# 27            27            28   50031    28    50031     PITT
# 28            28            29   50032    29    50032     PITT
# 29            29            30   50033    30    50033     PITT
# ...          ...           ...     ...   ...      ...      ...
# 1082        1082          1083   51558  1083    51558      SBL
# 1083        1083          1084   51559  1084    51559      SBL
# 1084        1084          1085   51560  1085    51560      SBL
# 1085        1085          1086   51561  1086    51561      SBL
# 1086        1086          1087   51562  1087    51562      SBL
# 1087        1087          1088   51563  1088    51563      SBL
# 1088        1088          1089   51564  1089    51564      SBL
# 1089        1089          1090   51565  1090    51565      SBL
# 1090        1090          1091   51566  1091    51566      SBL
# 1091        1091          1092   51567  1092    51567      SBL
# 1092        1092          1093   51568  1093    51568      SBL
# 1093        1093          1094   51569  1094    51569      SBL
# 1094        1094          1095   51570  1095    51570      SBL
# 1095        1095          1096   51571  1096    51571      SBL
# 1096        1096          1097   51572  1097    51572      SBL
# 1097        1097          1098   51573  1098    51573      SBL
# 1098        1098          1099   51574  1099    51574      SBL
# 1099        1099          1100   51575  1100    51575      SBL
# 1100        1100          1101   51576  1101    51576      SBL
# 1101        1101          1102   51577  1102    51577      SBL
# 1102        1102          1103   51578  1103    51578      SBL
# 1103        1103          1104   51579  1104    51579      SBL
# 1104        1104          1105   51580  1105    51580      SBL
# 1105        1105          1106   51581  1106    51581      SBL
# 1106        1106          1107   51582  1107    51582      SBL
# 1107        1107          1108   51583  1108    51583      SBL
# 1108        1108          1109   51584  1109    51584      SBL
# 1109        1109          1110   51585  1110    51585      SBL
# 1110        1110          1111   51606  1111    51606  MAX_MUN
# 1111        1111          1112   51607  1112    51607  MAX_MUN
#
#                FILE_ID  DX_GROUP  DSM_IV_TR  AGE_AT_SCAN     ...      \
# 0          no_filename         1          1        16.77     ...
# 1         Pitt_0050003         1          1        24.45     ...
# 2         Pitt_0050004         1          1        19.09     ...
# 3         Pitt_0050005         1          1        13.73     ...
# 4         Pitt_0050006         1          1        13.37     ...
# 5         Pitt_0050007         1          1        17.78     ...
# 6         Pitt_0050008         1          1        32.45     ...
# 7         Pitt_0050009         1          1        33.86     ...
# 8         Pitt_0050010         1          1        35.20     ...
# 9         Pitt_0050011         1          1        16.93     ...
# 10        Pitt_0050012         1          1        21.48     ...
# 11        Pitt_0050013         1          1         9.33     ...
# 12        Pitt_0050014         1          1        14.20     ...
# 13        Pitt_0050015         1          1        14.20     ...
# 14        Pitt_0050016         1          1        21.82     ...
# 15        Pitt_0050017         1          1        22.70     ...
# 16        Pitt_0050019         1          1        27.81     ...
# 17        Pitt_0050020         1          1        20.83     ...
# 18        Pitt_0050022         1          1        16.99     ...
# 19        Pitt_0050023         1          1        12.64     ...
# 20        Pitt_0050024         1          1        22.64     ...
# 21        Pitt_0050025         1          1        31.72     ...
# 22        Pitt_0050026         1          1        16.28     ...
# 23        Pitt_0050027         1          1        12.24     ...
# 24        Pitt_0050028         1          1        12.74     ...
# 25        Pitt_0050029         1          1        11.40     ...
# 26        Pitt_0050030         2          0        25.12     ...
# 27        Pitt_0050031         2          0        12.92     ...
# 28        Pitt_0050032         2          0        19.80     ...
# 29        Pitt_0050033         2          0        12.15     ...
# ...                ...       ...        ...          ...     ...
# 1082       SBL_0051558         2          0        27.00     ...
# 1083       SBL_0051559         2          0        27.00     ...
# 1084       SBL_0051560         2          0        27.00     ...
# 1085       SBL_0051561         2          0        36.00     ...
# 1086       SBL_0051562         2          0        37.00     ...
# 1087       SBL_0051563         2          0        38.00     ...
# 1088       SBL_0051564         2          0        39.00     ...
# 1089       SBL_0051565         2          0        39.00     ...
# 1090       SBL_0051566         2          0        41.00     ...
# 1091       SBL_0051567         2          0        34.00     ...
# 1092       SBL_0051568         2          0        37.00     ...
# 1093       SBL_0051569         2          0        36.00     ...
# 1094       SBL_0051570         2          0        42.00     ...
# 1095       SBL_0051571         1          1        22.00     ...
# 1096       SBL_0051572         1          2        28.00     ...
# 1097       SBL_0051573         1          3        30.00     ...
# 1098       SBL_0051574         1          2        30.00     ...
# 1099       SBL_0051575         1          2        31.00     ...
# 1100       SBL_0051576         1          3        31.00     ...
# 1101       SBL_0051577         1          3        31.00     ...
# 1102       SBL_0051578         1          2        33.00     ...
# 1103       SBL_0051579         1          3        41.00     ...
# 1104       SBL_0051580         1          3        42.00     ...
# 1105       SBL_0051581         1          3        64.00     ...
# 1106       SBL_0051582         1          2        31.00     ...
# 1107       SBL_0051583         1          2        35.00     ...
# 1108       SBL_0051584         1          2        49.00     ...
# 1109       SBL_0051585         1          1        27.00     ...
# 1110  MaxMun_a_0051606         1          2        29.00     ...
# 1111  MaxMun_a_0051607         1          2        26.00     ...
#
#       qc_notes_rater_1 qc_anat_rater_2  qc_anat_notes_rater_2  \
# 0                  NaN              OK                    NaN
# 1                  NaN              OK                    NaN
# 2                  NaN              OK                    NaN
# 3                  NaN              OK                    NaN
# 4                  NaN              OK                    NaN
# 5                  NaN              OK                    NaN
# 6                  NaN              OK                    NaN
# 7                  NaN              OK                    NaN
# 8                  NaN              OK                    NaN
# 9                  NaN              OK                    NaN
# 10                 NaN              OK                    NaN
# 11                 NaN              OK                    NaN
# 12                 NaN              OK                    NaN
# 13                 NaN              OK                    NaN
# 14                 NaN              OK                    NaN
# 15                 NaN           maybe    skull-striping fail
# 16                 NaN              OK                    NaN
# 17                 NaN              OK                    NaN
# 18                 NaN              OK                    NaN
# 19                 NaN              OK                    NaN
# 20                 NaN              OK                    NaN
# 21                 NaN              OK                    NaN
# 22                 NaN              OK                    NaN
# 23                 NaN              OK                    NaN
# 24                 NaN           maybe    skull-striping fail
# 25                 NaN           maybe    skull-striping fail
# 26                 NaN              OK                    NaN
# 27                 NaN              OK                    NaN
# 28                 NaN              OK                    NaN
# 29                 NaN              OK                    NaN
# ...                ...             ...                    ...
# 1082               NaN              OK                    NaN
# 1083               NaN              OK                    NaN
# 1084               NaN              OK                    NaN
# 1085               NaN              OK                    NaN
# 1086               NaN              OK                    NaN
# 1087               NaN              OK                    NaN
# 1088               NaN              OK                    NaN
# 1089               NaN              OK                    NaN
# 1090               NaN              OK                    NaN
# 1091               NaN              OK                    NaN
# 1092               NaN              OK                    NaN
# 1093               NaN              OK                    NaN
# 1094               NaN              OK                    NaN
# 1095               NaN              OK                    NaN
# 1096               NaN              OK                    NaN
# 1097               NaN              OK                    NaN
# 1098               NaN              OK                    NaN
# 1099               NaN              OK                    NaN
# 1100               NaN              OK                    NaN
# 1101               NaN              OK                    NaN
# 1102               NaN              OK                    NaN
# 1103               NaN              OK                    NaN
# 1104               NaN              OK                    NaN
# 1105               NaN              OK                    NaN
# 1106               NaN              OK                    NaN
# 1107               NaN              OK                    NaN
# 1108               NaN              OK                    NaN
# 1109               NaN              OK                    NaN
# 1110               NaN              OK                    NaN
# 1111               NaN              OK                    NaN
#
#       qc_func_rater_2            qc_func_notes_rater_2  qc_anat_rater_3  \
# 0                fail           ic-parietal-cerebellum               OK
# 1                  OK                              NaN               OK
# 2                  OK                              NaN               OK
# 3               maybe           ic-parietal-cerebellum               OK
# 4               maybe               ic-parietal slight               OK
# 5               maybe       ic-cerebellum_temporal_lob               OK
# 6                  OK                              NaN               OK
# 7                fail           ic-parietal-cerebellum               OK
# 8               maybe       ic-cerebellum_temporal_lob               OK
# 9               maybe       ic-cerebellum_temporal_lob               OK
# 10                 OK                              NaN               OK
# 11                 OK                              NaN               OK
# 12                 OK                              NaN               OK
# 13                 OK                              NaN               OK
# 14              maybe  ic-parietal-cerebellum_temporal               OK
# 15              maybe       ic-cerebellum_temporal_lob             fail
# 16               fail            ic-occipital_parietal               OK
# 17                 OK                              NaN               OK
# 18              maybe       ic-cerebellum_temporal_lob               OK
# 19              maybe      ic-cerebellum_temporal_lobe               OK
# 20              maybe       ic-cerebellum_temporal_lob               OK
# 21              maybe       ic-cerebellum_temporal_lob               OK
# 22              maybe       ic-cerebellum_temporal_lob               OK
# 23                 OK                    ic-cerebellum               OK
# 24              maybe           ic-parietal-cerebellum               OK
# 25               fail           ic-parietal-cerebellum               OK
# 26              maybe           ic-parietal-cerebellum               OK
# 27              maybe      ic-cerebellum_temporal_lobe               OK
# 28              maybe      ic-cerebellum_temporal_lobe               OK
# 29              maybe      ic-cerebellum_temporal_lobe               OK
# ...               ...                              ...              ...
# 1082            maybe      ic-cerebellum_temporal_lobe               OK
# 1083            maybe                    ic-cerebellum               OK
# 1084            maybe                    ic-cerebellum               OK
# 1085             fail           ic-parietal-cerebellum               OK
# 1086            maybe      ic-cerebellum_temporal_lobe               OK
# 1087            maybe      ic-cerebellum_temporal_lobe               OK
# 1088            maybe      ic-cerebellum-temporal_lobe               OK
# 1089            maybe      ic-cerebellum_temporal_lobe               OK
# 1090            maybe      ic-cerebellum-temporal_lobe               OK
# 1091            maybe      ic-cerebellum-temporal_lobe               OK
# 1092            maybe      ic-cerebellum-temporal_lobe               OK
# 1093            maybe      ic-cerebellum-temporal_lobe               OK
# 1094            maybe      ic-cerebellum-temporal_lobe               OK
# 1095             fail           ic-parietal-cerebellum               OK
# 1096            maybe      ic-cerebellum-temporal_lobe               OK
# 1097            maybe                    ic-cerebellum               OK
# 1098            maybe           ic-parietal-cerebellum               OK
# 1099             fail      ic-cerebellum-temporal_lobe               OK
# 1100            maybe                    ic-cerebellum               OK
# 1101            maybe      ic-cerebellum-temporal_lobe               OK
# 1102            maybe      ic-cerebellum-temporal_lobe               OK
# 1103            maybe      ic-cerebellum-temporal_lobe               OK
# 1104            maybe      ic-cerebellum-temporal_lobe               OK
# 1105             fail           ic-parietal-cerebellum               OK
# 1106            maybe                    ic-cerebellum               OK
# 1107               OK      ic-cerebellum-temporal_lobe               OK
# 1108            maybe                    vmpfc dropout               OK
# 1109            maybe      ic-cerebellum-temporal_lobe               OK
# 1110            maybe                    ic-cerebellum               OK
# 1111            maybe                    ic-cerebellum               OK
#
#      qc_anat_notes_rater_3 qc_func_rater_3 qc_func_notes_rater_3  SUB_IN_SMP
# 0                      NaN            fail             ERROR #24           1
# 1                      NaN              OK                   NaN           1
# 2                      NaN              OK                   NaN           1
# 3                      NaN              OK                   NaN           0
# 4                      NaN              OK                   NaN           1
# 5                      NaN              OK                   NaN           1
# 6                      NaN              OK                   NaN           1
# 7                      NaN              OK                   NaN           1
# 8                      NaN              OK                   NaN           1
# 9                      NaN              OK                   NaN           0
# 10                     NaN              OK                   NaN           1
# 11                     NaN              OK                   NaN           1
# 12                     NaN              OK                   NaN           1
# 13                     NaN              OK                   NaN           1
# 14                     NaN              OK                   NaN           1
# 15                   noise              OK                   NaN           1
# 16                     NaN              OK                   NaN           1
# 17                     NaN              OK                   NaN           1
# 18                     NaN              OK                   NaN           1
# 19                     NaN              OK                   NaN           0
# 20                     NaN              OK                   NaN           1
# 21                     NaN              OK                   NaN           1
# 22                     NaN              OK                   NaN           1
# 23                     NaN              OK                   NaN           1
# 24                     NaN              OK                   NaN           1
# 25                     NaN              OK                   NaN           0
# 26                     NaN              OK                   NaN           1
# 27                     NaN              OK                   NaN           1
# 28                     NaN              OK                   NaN           1
# 29                     NaN              OK                   NaN           1
# ...                    ...             ...                   ...         ...
# 1082                   NaN              OK                   NaN           0
# 1083                   NaN              OK                   NaN           0
# 1084                   NaN              OK                   NaN           0
# 1085                   NaN              OK                   NaN           0
# 1086                   NaN              OK                   NaN           0
# 1087                   NaN              OK                   NaN           0
# 1088                   NaN              OK                   NaN           0
# 1089                   NaN              OK                   NaN           0
# 1090                   NaN              OK                   NaN           0
# 1091                   NaN              OK                   NaN           0
# 1092                   NaN              OK                   NaN           0
# 1093                   NaN              OK                   NaN           0
# 1094                   NaN              OK                   NaN           0
# 1095                   NaN              OK                   NaN           0
# 1096                   NaN              OK                   NaN           0
# 1097                   NaN              OK                   NaN           0
# 1098                   NaN              OK                   NaN           0
# 1099                   NaN              OK                   NaN           0
# 1100                   NaN              OK                   NaN           0
# 1101                   NaN              OK                   NaN           0
# 1102                   NaN              OK                   NaN           0
# 1103                   NaN              OK                   NaN           0
# 1104                   NaN              OK                   NaN           0
# 1105                   NaN              OK                   NaN           0
# 1106                   NaN              OK                   NaN           0
# 1107                   NaN              OK                   NaN           0
# 1108                   NaN              OK                   NaN           0
# 1109                   NaN              OK                   NaN           0
# 1110                   NaN              OK                   NaN           0
# 1111                   NaN              OK                   NaN           1
#
# [1112 rows x 106 columns]
